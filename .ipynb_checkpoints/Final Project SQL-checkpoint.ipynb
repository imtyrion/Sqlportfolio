# %% [markdown]
# # INFO 6210 FINAL PROJECT SQL
# ## Twitter

# %%
import twitter # pip install twitter

# Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'zGisDmDd9cIGqIrVOFTVvVBIp'
CONSUMER_SECRET = 'Adndb1BQn3MP6UTRZrf46MHcvOs4toThpUpLXu9O8Yj7E2MZdN'
OAUTH_TOKEN = '116378647-fhCwWLIqRUz9kqUoiBAkgoK9l9fSHdF6oLFt2SYX'
OAUTH_TOKEN_SECRET = 'SfemAX8zWHlVpvlYlzqiJYcRC02K2sVNSEohUwnrnmgnv'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)

# %%
def twitter_trends(place, woe_id):
    results = twitter_api.trends.place(_id = woe_id)
    print ("%s Trends"%place)
    t=[]
    for location in results:
        for trend in location["trends"]:
            print (" - %s" % trend["name"])
            t.append(trend["name"])
    return t

# %%
woe_ids={'UK':23424975,'US':23424977,'WORLD':1}
uk_trends=twitter_trends('UK',woe_ids['UK'])
# Out:
# UK Trends
#  - #WWEGRR
#  - #MakeFilmsIrish
#  - #Gogglebox
#  - Fulham
#  - #grahamnortonshow
#  - #oldheadshotday
#  - Jeff Beck
#  - Mitrovic
#  - Girls Aloud
#  - Craven Cottage
#  - Katie Walsh
#  - Dean Richards
#  - matt baker
#  - Dan Evans
#  - The Undertaker
#  - Hoffenheim
#  - Joel Asoro
#  - Adam Lallana
#  - Josh Charnley
#  - Vikings
#  - Jake Wood
#  - Infinity War
#  - Prince Louis
#  - Amber Rudd
#  - #UltimateBoxxer
#  - #hignfy
#  - #thebutton
#  - #LEIvNEW
#  - #BelfastBusinessAwards
#  - #LateLateShow
#  - #SLCasWak
#  - #frontrowlate
#  - #EliteSeries
#  - #GardenersWorld
#  - #leeanddean
#  - #FAYouthCup
#  - #ANTM
#  - #PLCup
#  - #ManchesterMidnightWalk
#  - #FridayNight
#  - #edballsday
#  - #BeatBoss7QualifiersFinal
#  - #ELBA2018
#  - #RICSAwards
#  - #TheCityandTheCity
#  - #JDWPL
#  - #F4GLORY
#  - #godsofrag
#  - #ABBA
#  - #BrightonSEO

# %%
us_trends=twitter_trends('US',woe_ids['US'])
# Out:
# US Trends
#  - #WWEGRR
#  - Nick Chubb
#  - Will Hernandez
#  - #oldheadshotday
#  - Jim Brown
#  - #HowMenSayTheyreSorry
#  - Justin Tuck
#  - Antonio Gates
#  - Jason Witten
#  - #FlashbackFriday
#  - Daniel Bryan
#  - #VoterID
#  - Courtney Ramey
#  - Kremlin-linked
#  - Bob Lilly
#  - Shea Patterson
#  - RedState
#  - Round 2 of the 2018
#  - Yu Darvish
#  - Phil Coyne
#  - cass
#  - Strowman
#  - UIC Pavilion
#  - ESPN News
#  - James Ivory
#  - Bradley Beal
#  - Paul Junger Witt
#  - Trump Tower
#  - Brandon Morrow
#  - Sogard
#  - Jericho
#  - Fred VanVleet
#  - Otto Porter
#  - Austin Slater
#  - #ItGotSeriousWhen
#  - #MakeFilmsIrish
#  - #jbfa
#  - #4WideNats
#  - #ShabbatShalom
#  - #TORvsUTI
#  - #AMASummit
#  - #AwkwardMilestonesToCelebrate
#  - #WPGvsNSH
#  - #weekendvibes
#  - #ARCA
#  - #Stagecoach2018
#  - #BeerbongsandBentlys
#  - #DayOfSilence
#  - #CAALax
#  - #WHCD

# %%
import json

q = '#CardiB' 

n = 55

from urllib.parse import unquote

# See https://dev.twitter.com/rest/reference/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=n)

statuses = search_results['statuses']

for _ in range(5):
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError as e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=847960489447628799&q=%23RIPSelena&count=100&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Fri Apr 27 23:27:09 +0000 2018",
#  "id": 990009486441054209,
#  "id_str": "990009486441054209",
#  "text": "RT @DamarisRiveraxx: #datass #shebad #bbw #prettyfathoe #latina #cardib #yg #twerk #bbwbooty https://t.co/KBgKmof9rh",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "datass",
#     "indices": [
#      21,
#      28
#     ]
#    },
#    {
#     "text": "shebad",
#     "indices": [
#      29,
#      36
#     ]
#    },
#    {
#     "text": "bbw",
#     "indices": [
#      37,
#      41
#     ]
#    },
#    {
#     "text": "prettyfathoe",
#     "indices": [
#      42,
#      55
#     ]
#    },
#    {
#     "text": "latina",
#     "indices": [
#      56,
#      63
#     ]
#    },
#    {
#     "text": "cardib",
#     "indices": [
#      64,
#      71
#     ]
#    },
#    {
#     "text": "yg",
#     "indices": [
#      72,
#      75
#     ]
#    },
#    {
#     "text": "twerk",
#     "indices": [
#      76,
#      82
#     ]
# ...

# %%
for i in range(10):
    print()
    print(statuses[i]['text'])
    print('Favorites: ', statuses[i]['favorite_count'])
    print('Retweets: ', statuses[i]['retweet_count'])
# Out:
# RT @DamarisRiveraxx: #datass #shebad #bbw #prettyfathoe #latina #cardib #yg #twerk #bbwbooty https://t.co/KBgKmof9rh
# Favorites:  0
# Retweets:  11
#
# #SheBad #CardiB 😂 https://t.co/aQqONb5f6G
# Favorites:  0
# Retweets:  0
#
# #TeaCupBaeWatch 😍💗💋
# Cardi got that pregnancy glow🤰🏽✨
# #cardib #offset #baewatch #whatsthetea20… https://t.co/anOal38oqg
# Favorites:  0
# Retweets:  0
#
# RT @DamarisRiveraxx: #datass #shebad #bbw #prettyfathoe #latina #cardib #yg #twerk #bbwbooty https://t.co/KBgKmof9rh
# Favorites:  0
# Retweets:  11
#
# I say what I want, I ain't never been timid
# Only real shit comes out my mouth and only real niggas go in it #ido #cardib
# Favorites:  0
# Retweets:  0
#
# ..."You don't hit my line no more, oh, oh
# You don't make it ring, ring, ring, ring
# I can't keep this on the low
# I w… https://t.co/IPet9Fbl0r
# Favorites:  0
# Retweets:  0
#
# #CardiB got lawsuit problems... #thejasminebrand @JasmineBrandTHE @ Bronx, New York https://t.co/VB2IisCJqy
# ...

# %%
hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# %%
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
print(json.dumps(hashtags[0:5], indent=1))
# Out:
# [
#  "datass",
#  "shebad",
#  "bbw",
#  "prettyfathoe",
#  "latina"
# ]

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:]) # top 10
    print()
# Out:
# [('RT', 153), ('#CardiB', 123), ('@iamcardib', 72), ('the', 71), ('to', 62), ('I', 61), ('#cardib', 60), ('is', 55), ('and', 52), ('know', 48), ('a', 44), ('you', 42), ('for', 35), ('Cardi', 32), ('.', 32), ('on', 29), ('#Cardib', 28), ('where', 28), ('me', 26), ('with', 26), ('The', 25), ('it', 24), ('#BeCareful', 24), ('not', 24), ('get', 22), ('#NickiMinaj', 22), ('my', 21), ('rapper', 21), ('B', 20), ('her', 20), ('be', 19), ('in', 18), ('this', 18), ('now', 18), ('see', 18), ('#offset', 17), ('at', 17), ("I'm", 17), ('of', 17), ('BE', 16), ('CAREFUL', 16), ('REMIX🔥🔥🔥🔥Twitter', 16), ('help', 16), ('this🙏🏼🙏🏼🙌🏽🙌🏽🔥', 16), ('#Niakay', 16), ('@Itss_niakay:', 15), ('#Bardi', 15), ('#inva…', 15), ('by', 15), ('we', 15), ('your', 14), ('.@iamcardib', 14), ('says,', 14), ('"you', 14), ('at,', 14), ('be"', 14), ('#HTown.', 14), ('taking', 14), ('that', 13), ('out', 13), ('like', 13), ('was', 13), ('@abc13houston:', 13), ('som…', 13), ('from', 13), ('careful', 12), ('are', 12), ('so', 12), 
# ...

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['retweeted_status']['id'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status.keys()
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Tweet ID', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+----------------+--------------------+----------------------------------------------------+
# | Count | Screen Name    | Tweet ID           | Text                                               |
# +-------+----------------+--------------------+----------------------------------------------------+
# | 1976  | OffsetYRN      | 982113335050039296 | RT @OffsetYRN: I N V A S I O N O F P R I V A C Y   |
# |       |                |                    | #CardiB  O U T N O W https://t.co/4abr6MO3b9       |
# | 762   | aaronsciberras | 984663767567892480 | RT @aaronsciberras: I said "dance" not "fuck",     |
# |       |                |                    | don't get it confused. Had to set the record       |
# |       |                |                    | straight 'cause bitches love to assume.            |
# |       |                |                    |                                                    |
# ...

# %%
print(hashtags)
# Out:
# ['datass', 'shebad', 'bbw', 'prettyfathoe', 'latina', 'cardib', 'yg', 'twerk', 'bbwbooty', 'SheBad', 'CardiB', 'TeaCupBaeWatch', 'cardib', 'offset', 'baewatch', 'whatsthetea20', 'datass', 'shebad', 'bbw', 'prettyfathoe', 'latina', 'cardib', 'yg', 'twerk', 'bbwbooty', 'ido', 'cardib', 'CardiB', 'thejasminebrand', 'cardib', 'offset', 'blacklove', 'funnymemes', 'hiphop', 'ComedianRandiSkye', 'RickRoss', 'drake', 'CardiB', 'lilskies', 'lilpump', 'kodakblack', 'KingToddy', 'LivePD', 'NextUp', 'trap', 'beat', 'producer', 'brandnew', 'instrumental', 'trapbeat', 'rapbeat', 'burymeaking', 'postmalone', 'drake', 'blockboy', 'cardib', 'tekashi', 'kanye', 'Niakay', 'Cardib', 'Bardi', 'BeCareful', 'Billboard2018', 'CardiB', 'Ozuna', 'fashionnova', 'LetsGo', 'Hot97', '4eva', 'Cardib', 'voice', 'Niakay', 'Cardib', 'Bardi', 'BeCareful', 'spring', 'sandals', 'cardib', 'onlineboutique', 'onlineshopping', 'priorityshipping', 'JanelleMonáe', 'kaliuchis', 'CardiB', 'kimbra', 'CardiB', 'BeCareful', 'BeCar
# ...

# %%
import sqlite3

# %%
new_new = 'Assi.sqlite'
conn = sqlite3.connect(new_new)
c = conn.cursor()

# %%
conn.commit()

# %%
z =[]
for merge in hashtags:
    z.append(merge)
print(z)
# Out:
# ['datass', 'shebad', 'bbw', 'prettyfathoe', 'latina', 'cardib', 'yg', 'twerk', 'bbwbooty', 'SheBad', 'CardiB', 'TeaCupBaeWatch', 'cardib', 'offset', 'baewatch', 'whatsthetea20', 'datass', 'shebad', 'bbw', 'prettyfathoe', 'latina', 'cardib', 'yg', 'twerk', 'bbwbooty', 'ido', 'cardib', 'CardiB', 'thejasminebrand', 'cardib', 'offset', 'blacklove', 'funnymemes', 'hiphop', 'ComedianRandiSkye', 'RickRoss', 'drake', 'CardiB', 'lilskies', 'lilpump', 'kodakblack', 'KingToddy', 'LivePD', 'NextUp', 'trap', 'beat', 'producer', 'brandnew', 'instrumental', 'trapbeat', 'rapbeat', 'burymeaking', 'postmalone', 'drake', 'blockboy', 'cardib', 'tekashi', 'kanye', 'Niakay', 'Cardib', 'Bardi', 'BeCareful', 'Billboard2018', 'CardiB', 'Ozuna', 'fashionnova', 'LetsGo', 'Hot97', '4eva', 'Cardib', 'voice', 'Niakay', 'Cardib', 'Bardi', 'BeCareful', 'spring', 'sandals', 'cardib', 'onlineboutique', 'onlineshopping', 'priorityshipping', 'JanelleMonáe', 'kaliuchis', 'CardiB', 'kimbra', 'CardiB', 'BeCareful', 'BeCar
# ...

# %%
from collections import Counter
a = dict(Counter(z))
print(a)
# Out:
# {'datass': 7, 'shebad': 8, 'bbw': 7, 'prettyfathoe': 7, 'latina': 7, 'cardib': 63, 'yg': 7, 'twerk': 7, 'bbwbooty': 7, 'SheBad': 1, 'CardiB': 135, 'TeaCupBaeWatch': 1, 'offset': 18, 'baewatch': 1, 'whatsthetea20': 1, 'ido': 1, 'thejasminebrand': 1, 'blacklove': 2, 'funnymemes': 1, 'hiphop': 5, 'ComedianRandiSkye': 1, 'RickRoss': 1, 'drake': 9, 'lilskies': 1, 'lilpump': 1, 'kodakblack': 2, 'KingToddy': 1, 'LivePD': 1, 'NextUp': 1, 'trap': 6, 'beat': 1, 'producer': 1, 'brandnew': 1, 'instrumental': 1, 'trapbeat': 1, 'rapbeat': 1, 'burymeaking': 1, 'postmalone': 1, 'blockboy': 1, 'tekashi': 1, 'kanye': 1, 'Niakay': 16, 'Cardib': 29, 'Bardi': 16, 'BeCareful': 24, 'Billboard2018': 1, 'Ozuna': 3, 'fashionnova': 1, 'LetsGo': 1, 'Hot97': 1, '4eva': 1, 'voice': 1, 'spring': 1, 'sandals': 1, 'onlineboutique': 1, 'onlineshopping': 1, 'priorityshipping': 1, 'JanelleMonáe': 2, 'kaliuchis': 2, 'kimbra': 2, 'InvasionOfPrivacy': 9, 'krystaljung': 4, 'ICYMI': 2, 'Moments': 1, 'parents': 1, 'rapper': 
# ...

# %%
maximum = max(a, key=a.get)
maximum
# Out:
# 'CardiB'

# %%
import pandas as pd

# %%
hashTest1 = pd.DataFrame(z,columns=['Tags'])

# %%
hashTest1.duplicated().sum()
# Out:
# 630

# %%
hashTest2 = hashTest1.Tags.unique()

# %%
hashTest2
# Out:
# array(['datass', 'shebad', 'bbw', 'prettyfathoe', 'latina', 'cardib', 'yg',
#        'twerk', 'bbwbooty', 'SheBad', 'CardiB', 'TeaCupBaeWatch', 'offset',
#        'baewatch', 'whatsthetea20', 'ido', 'thejasminebrand', 'blacklove',
#        'funnymemes', 'hiphop', 'ComedianRandiSkye', 'RickRoss', 'drake',
#        'lilskies', 'lilpump', 'kodakblack', 'KingToddy', 'LivePD',
#        'NextUp', 'trap', 'beat', 'producer', 'brandnew', 'instrumental',
#        'trapbeat', 'rapbeat', 'burymeaking', 'postmalone', 'blockboy',
#        'tekashi', 'kanye', 'Niakay', 'Cardib', 'Bardi', 'BeCareful',
#        'Billboard2018', 'Ozuna', 'fashionnova', 'LetsGo', 'Hot97', '4eva',
#        'voice', 'spring', 'sandals', 'onlineboutique', 'onlineshopping',
#        'priorityshipping', 'JanelleMonáe', 'kaliuchis', 'kimbra',
#        'InvasionOfPrivacy', 'krystaljung', 'ICYMI', 'Moments', 'parents',
#        'rapper', 'cardiB', 'Becareful', 'HTown', 'Adoftheweek',
# ...

# %%
hashFinal = pd.DataFrame(hashTest2,columns=['Tags'])

# %%
hashFinal
# Out:
#                      Tags
# 0                  datass
# 1                  shebad
# 2                     bbw
# 3            prettyfathoe
# 4                  latina
# 5                  cardib
# 6                      yg
# 7                   twerk
# 8                bbwbooty
# 9                  SheBad
# 10                 CardiB
# 11         TeaCupBaeWatch
# 12                 offset
# 13               baewatch
# 14          whatsthetea20
# 15                    ido
# 16        thejasminebrand
# 17              blacklove
# 18             funnymemes
# 19                 hiphop
# 20      ComedianRandiSkye
# 21               RickRoss
# 22                  drake
# 23               lilskies
# 24                lilpump
# 25             kodakblack
# 26              KingToddy
# 27                 LivePD
# 28                 NextUp
# 29                   trap
# ..                    ...
# 374            BlackWoman
# 375            BlackWomen
# 376                   gay
# ...

# %% [markdown]
# ## YOUTUBE

# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser
import pandas as pd
import pprint 
import matplotlib.pyplot as pd

# %%
DEVELOPER_KEY = "AIzaSyB-n64zotDUwx-L6Njm6RRBouNNK1Vub6k"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

    search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=max_results,
    location=location,
    locationRadius=location_radius).execute()

    title = []
    channelId = []
    channelTitle = []
    categoryId = []
    videoId = []
    viewCount = []
    likeCount = []
    dislikeCount = []
    commentCount = []
    favoriteCount = []
    category = []
    tags = []
    videos = []
    
    for search_result in search_response.get("items", []):
    	if search_result["id"]["kind"] == "youtube#video":

            title.append(search_result['snippet']['title']) 

            videoId.append(search_result['id']['videoId'])

            response = youtube.videos().list(
                part='statistics, snippet',
                id=search_result['id']['videoId']).execute()

            channelId.append(response['items'][0]['snippet']['channelId'])
            channelTitle.append(response['items'][0]['snippet']['channelTitle'])
            categoryId.append(response['items'][0]['snippet']['categoryId'])
            favoriteCount.append(response['items'][0]['statistics']['favoriteCount'])
            viewCount.append(response['items'][0]['statistics']['viewCount'])
            likeCount.append(response['items'][0]['statistics']['likeCount'])
            dislikeCount.append(response['items'][0]['statistics']['dislikeCount'])
 
            if 'commentCount' in response['items'][0]['statistics'].keys():
                commentCount.append(response['items'][0]['statistics']['commentCount'])
            else:
                commentCount.append([])
	  
            if 'tags' in response['items'][0]['snippet'].keys():
                tags.append(response['items'][0]['snippet']['tags'])
            else:
                tags.append([])
    print(tags)
    youtube_dict = {'tags':tags,'channelId': channelId,'channelTitle': channelTitle,'categoryId':categoryId,'title':title,'videoId':videoId,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount,'favoriteCount':favoriteCount}

    return youtube_dict

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
test = youtube_search("CardiB")
test.keys()
# Out:
# [['Cardi B', 'Bodak Yellow', 'Official Music Video', 'Bodak Yellow Music Video', 'New Cardi B', 'Cardi B Music Video', 'Cardi Video', 'Cardi B Bodak Yellow', 'Money Moves', 'Cardi B Money Moves', 'Bodak Yellow Cardi B', 'Cardi B Pregnant', 'Cardi B Offset', 'Cardi B Album', 'Cardi B Leak', 'Cardi B - Invasion of Privacy', 'Cardi B Billboard', 'Cardi B Sex Tape', 'Cardi B Music', 'Cardi B - Bodak Yellow', 'Cardi B Amazon'], ['Cardi B', 'Be Careful', 'Bodak Yellow', 'Invasion of Privacy', 'Love and Hip Hop', 'New Cardi B', 'No Limit', 'No Limit Cardi B', 'Cardi B Bodak Yellow', 'Bartier Cardi', 'Offset Cheating', 'Offset Cardi B', 'Cardi b - Be Careful [official audio]', 'Cardi B - Invasion of Privacy', 'Cardi B Album', 'Cardi B Bartier Cardi', 'Hennesy Carolina', 'Motorsport Cardi B', 'Finesse Remix Cardi B', 'Cardi B Music', 'Cardi B LEak', 'Cardi B Audio'], ['Cardi B', 'SZA', 'I Do', 'Invasion of Privacy', 'Hip Hop', 'Rap', 'Atlantic Records', 'Bronx', 'New York', 'Audio', 'Official
# ...

# %%
test['commentCount'][:5]
# Out:
# ['302225', '37225', '8076', '21619', '57340']

# %%
df = pd.DataFrame(data=test)
df.head()
# Out:
#   categoryId                 channelId channelTitle commentCount dislikeCount  \
# 0         22  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B       302225       436072
# 1         22  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B        37225        26837
# 2         10  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B         8076         6318
# 3         22  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B        21619        16720
# 4         10  UCjIA3wwhi0QjSOXAZwOXbPA        Ozuna        57340        94710
#
#   favoriteCount likeCount                                               tags  \
# 0             0   3983360  [Cardi B, Bodak Yellow, Official Music Video, ...
# 1             0    473693  [Cardi B, Be Careful, Bodak Yellow, Invasion o...
# 2             0    223293  [Cardi B, SZA, I Do, Invasion of Privacy, Hip ...
# 3             0    322957  [Cardi B, Drip, Migos, Motorsport, Offset, Qua...
# 4             0   1510769  [Ozuna, Reggaeton, Odisea, Odisea The Album, L...
#
# ...

# %% [markdown]
# ### The following Queries are performed on MySqlWorkbench.
# Screenshots of the following questions are attached.

# %% [markdown]
# ### Question 1. How viral are my posts?
# <img src="one.png">
# To calculate the virality of the post, we have taken the 'View Count' into consideration, and hence the highest view count is the most Viral Post.

# %% [markdown]
# ### Question 2. What topics are trending in my DOMAIN?
# <img src="two.png">
# Since we have selected the music domain, the following output show are the trending topics in the 'MUSIC' domain.

# %% [markdown]
# ### Question 3. What's my reach?
# <img src="three.png">
# We have used the ViewCount, LikeCount, and Comment Count to see the reach of the particular User.

# %% [markdown]
# ### Question 4. Who should I be following?
# <img src="four.png">
# It is simple to understand who you'd want to follow, the most popular user on the social media. Hence we have used to calculate the popularity by using the Like Count of the user.

# %% [markdown]
# ### Question 5. What are people saying about me(somebody)?
# <img src="five.png">
# To answer this question, we have retrieved the related tags for particular users, and these tags determine what people are saying about them.

# %% [markdown]
# ### Question 6. How much influence do my posts have?
# <img src="six.png">
# We have answered this question by using Youtube Data API. The influence of the post is by seeing the view count of the particular video. As people watch these videos and are influenced by them, and they hence get trending.

# %% [markdown]
# ### Question 7. Should I add a picture or a URL to my post?
# <img src="seven.png">
# We have used a FILTER called LIKE, and hence we have filtered our data by using the Keyword 'http and https'.

# %% [markdown]
# ### Question 8. What hashtags or Keywords should I add to my post?
# <img src="eight.png">

# %% [markdown]
# ### Question 9. What is the best time to post?
# <img src="nine.png">

# %% [markdown]
# ### Question 10. Should I follow somebody back?
# <img src="ten.png">
# We think that the users deserve to follow members who have more than 10,000 likes on their channel, hence we have acquired the list of Youtubers and Youtube Channel who have many likes.

# %% [markdown]
# ### Question 11. What users post like me?
# <img src="eleven.png">

# %% [markdown]
# ### Question 12. What posts are like mine?
# <img src="twelve.png">
# We have used the retweets that people have made about the particular artist or domain, or whenever they have talked about them. Hence we have made a list of the people who have retweeted something about an artist in ourdomain.

# %% [markdown]
# ### THE END
# #### By Anjaneya and Nidhi.
