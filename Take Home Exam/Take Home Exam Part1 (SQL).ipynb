# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
song= pd.read_csv("billboardsongs.csv",encoding='latin1')

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 7 columns):
# Song_id    5100 non-null int64
# Rank       5100 non-null int64
# Song       5100 non-null object
# Artist     5100 non-null object
# Year       5100 non-null int64
# Lyrics     4913 non-null object
# Source     4913 non-null float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 279.0+ KB

# %%
song.isnull().sum()
# Out:
# Song_id      0
# Rank         0
# Song         0
# Artist       0
# Year         0
# Lyrics     187
# Source     187
# dtype: int64

# %%
song.dropna()
# Out:
#       Song_id  Rank                                      Song  \
# 0           1     1                               wooly bully
# 1           2     2  i cant help myself sugar pie honey bunch
# 2           3     3                i cant get no satisfaction
# 3           4     4                       you were on my mind
# 4           5     5              youve lost that lovin feelin
# 5           6     6                                  downtown
# 6           7     7                                      help
# 7           8     8               cant you hear my heart beat
# 8           9     9                      crying in the chapel
# 9          10    10                                   my girl
# 10         11    11                            help me rhonda
# 11         12    12                          king of the road
# 12         13    13                    the birds and the bees
# 13         14    14                 hold me thrill me kiss me
# ...

# %%
song.isnull().sum()
# Out:
# Song_id      0
# Rank         0
# Song         0
# Artist       0
# Year         0
# Lyrics     187
# Source     187
# dtype: int64

# %%
song.dropna(how='all')
# Out:
#       Song_id  Rank                                      Song  \
# 0           1     1                               wooly bully
# 1           2     2  i cant help myself sugar pie honey bunch
# 2           3     3                i cant get no satisfaction
# 3           4     4                       you were on my mind
# 4           5     5              youve lost that lovin feelin
# 5           6     6                                  downtown
# 6           7     7                                      help
# 7           8     8               cant you hear my heart beat
# 8           9     9                      crying in the chapel
# 9          10    10                                   my girl
# 10         11    11                            help me rhonda
# 11         12    12                          king of the road
# 12         13    13                    the birds and the bees
# 13         14    14                 hold me thrill me kiss me
# ...

# %%
song.dropna(axis=0, how='all')
# Out:
#       Song_id  Rank                                      Song  \
# 0           1     1                               wooly bully
# 1           2     2  i cant help myself sugar pie honey bunch
# 2           3     3                i cant get no satisfaction
# 3           4     4                       you were on my mind
# 4           5     5              youve lost that lovin feelin
# 5           6     6                                  downtown
# 6           7     7                                      help
# 7           8     8               cant you hear my heart beat
# 8           9     9                      crying in the chapel
# 9          10    10                                   my girl
# 10         11    11                            help me rhonda
# 11         12    12                          king of the road
# 12         13    13                    the birds and the bees
# 13         14    14                 hold me thrill me kiss me
# ...

# %%
song.isnull().sum()
# Out:
# Song_id      0
# Rank         0
# Song         0
# Artist       0
# Year         0
# Lyrics     187
# Source     187
# dtype: int64

# %%
song.dropna()
# Out:
#       Song_id  Rank                                      Song  \
# 0           1     1                               wooly bully
# 1           2     2  i cant help myself sugar pie honey bunch
# 2           3     3                i cant get no satisfaction
# 3           4     4                       you were on my mind
# 4           5     5              youve lost that lovin feelin
# 5           6     6                                  downtown
# 6           7     7                                      help
# 7           8     8               cant you hear my heart beat
# 8           9     9                      crying in the chapel
# 9          10    10                                   my girl
# 10         11    11                            help me rhonda
# 11         12    12                          king of the road
# 12         13    13                    the birds and the bees
# 13         14    14                 hold me thrill me kiss me
# ...

# %%
song.isnull()
# Out:
#       Song_id   Rank   Song  Artist   Year  Lyrics  Source
# 0       False  False  False   False  False   False   False
# 1       False  False  False   False  False   False   False
# 2       False  False  False   False  False   False   False
# 3       False  False  False   False  False   False   False
# 4       False  False  False   False  False   False   False
# 5       False  False  False   False  False   False   False
# 6       False  False  False   False  False   False   False
# 7       False  False  False   False  False   False   False
# 8       False  False  False   False  False   False   False
# 9       False  False  False   False  False   False   False
# 10      False  False  False   False  False   False   False
# 11      False  False  False   False  False   False   False
# 12      False  False  False   False  False   False   False
# 13      False  False  False   False  False   False   False
# 14      False  False  False   False  False   False   False
# ...

# %%
song.isnull().sum()
# Out:
# Song_id      0
# Rank         0
# Song         0
# Artist       0
# Year         0
# Lyrics     187
# Source     187
# dtype: int64

# %%
song.isnull()
# Out:
#       Song_id   Rank   Song  Artist   Year  Lyrics  Source
# 0       False  False  False   False  False   False   False
# 1       False  False  False   False  False   False   False
# 2       False  False  False   False  False   False   False
# 3       False  False  False   False  False   False   False
# 4       False  False  False   False  False   False   False
# 5       False  False  False   False  False   False   False
# 6       False  False  False   False  False   False   False
# 7       False  False  False   False  False   False   False
# 8       False  False  False   False  False   False   False
# 9       False  False  False   False  False   False   False
# 10      False  False  False   False  False   False   False
# 11      False  False  False   False  False   False   False
# 12      False  False  False   False  False   False   False
# 13      False  False  False   False  False   False   False
# 14      False  False  False   False  False   False   False
# ...

# %%
song.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 5070    False
# 5071    False
# 5072    False
# 5073    False
# 5074    False
# 5075    False
# 5076    False
# 5077    False
# 5078    False
# 5079    False
# 5080    False
# 5081    False
# 5082    False
# 5083    False
# 5084    False
# 5085    False
# 5086    False
# 5087    False
# 5088    False
# 5089    False
# 5090    False
# 5091    False
# 5092    False
# 5093    False
# 5094    False
# 5095    False
# 5096    False
# 5097    False
# 5098    False
# 5099    False
# ...

# %%
song.isnull().sum()
# Out:
# Song_id      0
# Rank         0
# Song         0
# Artist       0
# Year         0
# Lyrics     187
# Source     187
# dtype: int64

# %%
import sqlite3

# %%
conn = sqlite3.connect("billboard.db")
c = conn.cursor()
song.to_sql("sarode",conn,if_exists='replace',index=False)

# %% [markdown]
# #### Create SongTable as Table name for billboardsongs.csv

# %%
song.to_sql('billtable',
           con=conn,
           if_exists='replace',
           index=False)

# %% [markdown]
# #### Display first 10 rows from Songs Table

# %%
df = pd.read_sql('SELECT * FROM billtable LIMIT 10', con=conn)
print(df)
# Out:
#    Song_id  Rank                                      Song  \
# 0        1     1                               wooly bully
# 1        2     2  i cant help myself sugar pie honey bunch
# 2        3     3                i cant get no satisfaction
# 3        4     4                       you were on my mind
# 4        5     5              youve lost that lovin feelin
# 5        6     6                                  downtown
# 6        7     7                                      help
# 7        8     8               cant you hear my heart beat
# 8        9     9                      crying in the chapel
# 9       10    10                                   my girl
#
#                           Artist  Year  \
# 0  sam the sham and the pharaohs  1965
# 1                      four tops  1965
# 2             the rolling stones  1965
# 3                        we five  1965
# 4         the righteous brothers  1965
# 5                   petula clark  1965
# ...

# %% [markdown]
# ## QUESTIONS

# %% [markdown]
# ### 1. Select Columns

# %% [markdown]
# ##### Selecting Rank and Artist from SongTable

# %%
df = pd.read_sql('SELECT Rank,Artist FROM billtable', con=conn)
print(df)
# Out:
#       Rank                                             Artist
# 0        1                      sam the sham and the pharaohs
# 1        2                                          four tops
# 2        3                                 the rolling stones
# 3        4                                            we five
# 4        5                             the righteous brothers
# 5        6                                       petula clark
# 6        7                                        the beatles
# 7        8                                    hermans hermits
# 8        9                                      elvis presley
# 9       10                                    the temptations
# 10      11                                     the beach boys
# 11      12                                       roger miller
# 12      13                                        jewel akens
# 13      14                                         mel carter
# ...

# %% [markdown]
# ### 2. Filtering Rows

# %% [markdown]
# #### Selecting all the Song information with Rank 1 from YEAR 1965 - 2015

# %%
df = pd.read_sql('SELECT * FROM billtable WHERE Rank=1', con=conn)
print(df)
# Out:
#     Song_id  Rank                                               Song  \
# 0         1     1                                        wooly bully
# 1       101     1                         ballad of the green berets
# 2       201     1                                   to sir with love
# 3       301     1                                           hey jude
# 4       401     1                                        sugar sugar
# 5       501     1                         bridge over troubled water
# 6       601     1                                   joy to the world
# 7       701     1                the first time ever i saw your face
# 8       801     1         tie a yellow ribbon round the ole oak tree
# 9       901     1                                    the way we were
# 10     1001     1                         love will keep us together
# 11     1101     1                                   silly love songs
# 12     1201     1                tonights the night gonna be alright
# ...

# %% [markdown]
# #### Displaying Rank, Artist and Song from the year 2015, ranked from 1-100

# %%
df = pd.read_sql('SELECT Rank,Artist,Song,Year FROM billtable WHERE Year=2015', con=conn)
print(df)
# Out:
#     Rank                                             Artist  \
# 0      1                   mark ronson featuring bruno mars
# 1      2                                         ed sheeran
# 2      3                 wiz khalifa featuring charlie puth
# 3      4                                          fetty wap
# 4      5                                           maroon 5
# 5      6                                      walk the moon
# 6      7                                       taylor swift
# 7      8                                            silento
# 8      9                                         the weeknd
# 9     10                                         the weeknd
# 10    11                                                omi
# 11    12                                         the weeknd
# 12    13                                     ellie goulding
# 13    14                                             hozier
# 14    15              taylor swift featuring kendrick lamar
# ...

# %% [markdown]
# ### 3. Sort the Query

# %% [markdown]
# #### Sorting the Artist list Alphabetically (Ascending order)

# %%
df = pd.read_sql('SELECT Rank,Artist FROM billtable ORDER BY Artist ASC', con=conn)
print(df)
# Out:
#       Rank                                             Artist
# 0        5                                     the mysterians
# 1       84                             100 proof aged in soul
# 2       40                                      10000 maniacs
# 3       42                                               10cc
# 4       44                                               10cc
# 5       37                                                112
# 6       20                                                112
# 7       68                                                112
# 8       97                           112 featuring foxy brown
# 9       47                             112 featuring lil zane
# 10      34           112 featuring the notorious big and mase
# 11      33                              1910 fruitgum company
# 12      48                              1910 fruitgum company
# 13      67                              1910 fruitgum company
# ...

# %% [markdown]
# ### 4. Group by an  an attribute

# %% [markdown]
# #### Grouping by Year

# %%
df = pd.read_sql('SELECT Artist,Year FROM billtable GROUP BY Year', con=conn)
print(df)
# Out:
#                                     Artist  Year
# 0                              marvin gaye  1965
# 1                           wilson pickett  1966
# 2                             neil diamond  1967
# 3                             jerry butler  1968
# 4                             the box tops  1969
# 5                          aretha franklin  1970
# 6                               perry como  1971
# 7                       the isley brothers  1972
# 8                          the temptations  1973
# 9                             the spinners  1974
# 10             discotex and the sexolettes  1975
# 11                           glen campbell  1976
# 12                             cj  company  1977
# 13                              steely dan  1978
# 14                                firefall  1979
# 15         tom petty and the heartbreakers  1980
# 16                               andy gibb  1981
# 17                            stevie nicks  1982
# ...

# %% [markdown]
# ### 5. Calculate an aggregate function on an attribute of the group

# %% [markdown]
# #### Count of Artist in a particular year by using Group By

# %%
df = pd.read_sql('SELECT COUNT(Artist),Year FROM billtable GROUP BY Year', con=conn)
print(df)
# Out:
#     COUNT(Artist)  Year
# 0             100  1965
# 1             100  1966
# 2             100  1967
# 3             100  1968
# 4             100  1969
# 5             100  1970
# 6             100  1971
# 7             100  1972
# 8             100  1973
# 9             100  1974
# 10            100  1975
# 11            100  1976
# 12            100  1977
# 13            100  1978
# 14            100  1979
# 15            100  1980
# 16            100  1981
# 17            100  1982
# 18            100  1983
# 19            100  1984
# 20            100  1985
# 21            100  1986
# 22            100  1987
# 23            100  1988
# 24            100  1989
# 25            100  1990
# 26            100  1991
# 27            100  1992
# 28            100  1993
# 29            100  1994
# 30            100  1995
# 31            100  1996
# 32            100  1997
# 33            100  1998
# 34            100  1999
# 35            100  2000
# 36            100  2001
# ...

# %% [markdown]
# ### 6. Use DISTINCT keyword will make it so it only returns one instance of each attribute.

# %% [markdown]
# #### Select Distinct Artist from the year 2015

# %%
df = pd.read_sql('SELECT DISTINCT Artist FROM billtable WHERE Year=2015', con=conn)
print(df)
# Out:
#                                                Artist
# 0                    mark ronson featuring bruno mars
# 1                                          ed sheeran
# 2                  wiz khalifa featuring charlie puth
# 3                                           fetty wap
# 4                                            maroon 5
# 5                                       walk the moon
# 6                                        taylor swift
# 7                                             silento
# 8                                          the weeknd
# 9                                                 omi
# 10                                     ellie goulding
# 11                                             hozier
# 12              taylor swift featuring kendrick lamar
# 13              major lazer and dj snake featuring mo
# 14                                       jason derulo
# 15         skrillex and diplo featuring justin bieber
# ...

# %%
df = pd.read_sql('SELECT * FROM billtable', con=conn)
print(df)
# Out:
#       Song_id  Rank                                      Song  \
# 0           1     1                               wooly bully
# 1           2     2  i cant help myself sugar pie honey bunch
# 2           3     3                i cant get no satisfaction
# 3           4     4                       you were on my mind
# 4           5     5              youve lost that lovin feelin
# 5           6     6                                  downtown
# 6           7     7                                      help
# 7           8     8               cant you hear my heart beat
# 8           9     9                      crying in the chapel
# 9          10    10                                   my girl
# 10         11    11                            help me rhonda
# 11         12    12                          king of the road
# 12         13    13                    the birds and the bees
# 13         14    14                 hold me thrill me kiss me
# ...

# %% [markdown]
# ### 7. Create a column that is calculated from other columns.

# %%
df = pd.read_sql('SELECT Song ||" Song Released In "|| Year AS ReleaseYear FROM billtable', con=conn)
print(df)
# Out:
#                                             ReleaseYear
# 0                     wooly bully Song Released In 1965
# 1     i cant help myself sugar pie honey bunch Song ...
# 2      i cant get no satisfaction Song Released In 1965
# 3             you were on my mind Song Released In 1965
# 4     youve lost that lovin feelin Song Released In ...
# 5                        downtown Song Released In 1965
# 6                            help Song Released In 1965
# 7     cant you hear my heart beat Song Released In 1965
# 8            crying in the chapel Song Released In 1965
# 9                         my girl Song Released In 1965
# 10                 help me rhonda Song Released In 1965
# 11               king of the road Song Released In 1965
# 12         the birds and the bees Song Released In 1965
# 13      hold me thrill me kiss me Song Released In 1965
# 14                        shotgun Song Released In 1965
# 15                 i got you babe Song Released In 1965
# ...

# %% [markdown]
# #### Adding 'Song Released In' in the column 'ReleaseYear

# %%
df = pd.read_sql('SELECT *,Song ||" Song Released In "|| Year AS ReleaseYear FROM billtable', con=conn)
print(df)
# Out:
#       Song_id  Rank                                      Song  \
# 0           1     1                               wooly bully
# 1           2     2  i cant help myself sugar pie honey bunch
# 2           3     3                i cant get no satisfaction
# 3           4     4                       you were on my mind
# 4           5     5              youve lost that lovin feelin
# 5           6     6                                  downtown
# 6           7     7                                      help
# 7           8     8               cant you hear my heart beat
# 8           9     9                      crying in the chapel
# 9          10    10                                   my girl
# 10         11    11                            help me rhonda
# 11         12    12                          king of the road
# 12         13    13                    the birds and the bees
# 13         14    14                 hold me thrill me kiss me
# ...

# %% [markdown]
# ### 8. Count all of the null values in a nullable field.

# %%
df = pd.read_sql('SELECT COUNT(Lyrics) FROM billtable WHERE Lyrics is Null', con=conn)
print(df)
# Out:
#    COUNT(Lyrics)
# 0              0

# %% [markdown]
# ### 9.  In a text field count all of rows in the columns that contain the letter 'a'.

# %%
df = pd.read_sql('SELECT COUNT(Song) FROM billtable WHERE Song LIKE "%a%"', con=conn)
print(df)
# Out:
#    COUNT(Song)
# 0         3142

# %% [markdown]
# ## Question 10 in SocialMedia.ipynb
#
# ### SocialMedia.ipynb is another Database which contains the Youtube data which I have previously acquired by using the Youtube API. This table contains many different values which was easier to form queries as the queries with this database makes more sense.

# %% [markdown]
# ### 11. Computationally what is the most expensive operation in the relational data model?
#
# #### Join is an amazing building block, which you need to use wisely.
# ##### First I would like to address an opinion that “joins have a quadratic complexity (O(n^2)) in both time and space”. This is simply not true. In practice joins usually have O(1) (nested loop and merge join) or O(N) (hash join) space complexity, and M*logN and logM + logN (nested loop join with an index lookup on the inner side) or M + N (merge join or hash join) complexity in time, where M and N are the cardinalities of each side of the join.
# ##### Joins and SQL in general are also one of the most expressive tools for analytical queries.
# ##### Joins can be “bad” because you can concisely express a lot of computational complexity, and system that allow join can have “bad neighbors”. That’s why if you have a lot of developers working on a shared real-time system it makes sense sometimes to restrict your api to not allow them.

# %% [markdown]
# # For Question 12, 17, 19, 20, 21, 22, 24, 25, 26, 27 ---> I have used MySqlWorkbench. Screenshots are attached for these questions.

# %% [markdown]
# ### 12. Write a function to calculate something relevant to your project.  Show that it works.

# %% [raw]
# CREATE FUNCTION `TotalViewCount` (View1 Varchar(150))
# RETURNS INTEGER
# BEGIN
# Declare j int(11);
# select channelTitle,sum(viewcount) into j  from youtube where channelTitle= View1;
# RETURN j;
# END

# %% [markdown]
# <img src="func.png">

# %% [markdown]
# ### 13.  When two tables are joined in a relational database what is the resulting data structure?
# #### It will create a Table which contains columns and rows with all the attributes from both the tables.

# %% [markdown]
# ## Question 14 in SocialMedia.ipynb

# %% [markdown]
# ## Question 15 in SocialMedia.ipynb

# %% [markdown]
# ### 16. Why create views?
# #### 1. Views can hide complexity
# #### If you have a query that requires joining several tables, or has complex logic or calculations, you can code all that logic into a view, then select from the view just like you would a table.
#
# #### 2. Views can be used as a security mechanism
# #### A view can select certain columns and/or rows from a table, and permissions set on the view instead of the underlying tables. This allows surfacing only the data that a user needs to see.
#
# #### 3. Views can simplify supporting legacy code
# #### If you need to refactor a table that would break a lot of code, you can replace the table with a view of the same name. The view provides the exact same schema as the original table, while the actual schema has changed. This keeps the legacy code that references the table from breaking, allowing you to change the legacy code at your leisure

# %% [markdown]
# ### 17. Select and filter some data from a table created by a view.

# %% [raw]
# create VIEW [y]  As
# select column_1,Title,ViewCount,channeltitle from youtube
# select * from y
# where channeltitle = 'Cardi B'

# %% [markdown]
# <img src="view1.png">

# %% [markdown]
# ### 18.  Why create temporary tables?
# #### A temporary table in SQL Server, as the name suggests, is a database table that exists temporarily on the database server. A temporary table stores a subset of data from a normal table for a certain period of time. Temporary tables are particularly useful when you have a large number of records in a table and you repeatedly need to interact with a small subset of those records. In such cases instead of filtering the data again and again to fetch the subset, you can filter the data once and store it in a temporary table. You can then execute your queries on that temporary table. Temporary tables are stored inside “tempdb” which is a system database. Let’s take a look at how you can use a temporary data in a simple scenario.

# %% [markdown]
# ### 19. Select and filter some data from a table created by a temporary table.

# %% [raw]
# select * into #temp from youtube
# select * from #temp where channeltitle = 'Cardi B'

# %% [markdown]
# <img src="temp1.png">

# %% [markdown]
# ### 20. Insert some data in to a table.

# %% [raw]
# insert into #temp values(152,'nidhi',100000000000,'11langdon','5555555',8888888888,0,'NA')

# %% [markdown]
# #### I lost the output image, but the above query worked for me.

# %% [markdown]
# ### 21. Update some data in a table.

# %% [raw]
# update #temp set channelTitle = 'Suman' where Column_1=2

# %% [markdown]
# <img src="temp2.png">

# %% [markdown]
# ### 22. Delete some data a table.

# %% [raw]
# delete from #temp  where Column_1=3

# %% [markdown]
# <img src="temp3.png">

# %% [markdown]
# ### 23. Create a  stored routine that does something useful for your project.
# #### For this answer as far as I know, there is no difference between Store routine and Stored Procedure. Hence I further looked up online to find more information about Stored Routine, but couldn't complete this.
# #### I have completed the Stored Procedure answer (24)

# %% [markdown]
# ### 24. Stored Procedure

# %% [raw]
# CREATE DEFINER=`root`@`localhost` PROCEDURE `Dislike`(In Dislike int(11))
# BEGIN
# select * from youtube where dislikecount < Dislike;

# %% [markdown]
# <img src="store1.png">
# <img src="store2.png">
# <img src="store3.png">

# %% [markdown]
# ### 25.  Create a index on a non-key attribute. Does it help?
# <img src="index.png">

# %% [markdown]
# ### 26. Create a trigger.
# <img src="trigger.png">

# %% [markdown]
# ### 27. Create a transaction.

# %% [raw]
# BEGIN TRANSACTION;
# DELETE FROM youtube
#     WHERE column_1 = 1
#
# Update youtube set column_1 = 1 where column_1 = 2
#
# COMMIT

# %% [markdown]
# <img src="trans.png">

# %% [markdown]
# ## 28 Explain to an eight year old (i.e. your professor) what are the first  three Normal Forms.
# #### Problems Without Normalization:
# #### If a table is not properly normalized and have data redundancy then it will not only eat up extra memory space but will also make it difficult to handle and update the database, without facing data loss. Insertion, Updation and Deletion Anamolies are very frequent if database is not normalized. To understand these anomalies let us take an example of a Student table
# <img src="nf.png">
# #### In the table above, we have data of 4 Computer Sci. students. As we can see, data for the fields branch, hod(Head of Department) and office_tel is repeated for the students who are in the same branch in the college, this is Data Redundancy.
# ### Insertion Anamoly
# #### Suppose for a new admission, until and unless a student opts for a branch, data of the student cannot be inserted, or else we will have to set the branch information as NULL.Also, if we have to insert data of 100 students of same branch, then the branch information will be repeated for all those 100 students.These scenarios are nothing but Insertion anomalies.
# ### Updation Anomaly
# #### What if Mr. X leaves the college? or is no longer the HOD of computer science department? In that case all the student records will have to be updated, and if by mistake we miss any record, it will lead to data inconsistency. This is Updation anomaly.
# ### Deletion Anomaly
# #### In our Student table, two different informations are kept together, Student information and Branch information. Hence, at the end of the academic year, if student records are deleted, we will also lose the branch information. This is Deletion anomaly.
# ### Normalization Rule
# #### Normalization rules are divided into the following normal forms:
# #### 1. First Normal Form
# #### 2. Second Normal Form
# #### 3. Third Normal Form
# #### 4. BCNF
#
# ## First Normal Form (1NF)
# ### For a table to be in the First Normal Form, it should follow the following 4 rules:
# #### 1. It should only have single(atomic) valued attributes/columns.
# #### 2. Values stored in a column should be of the same domain
# #### 3. All the columns in a table should have unique names.
# #### 4. And the order in which data is stored, does not matter.
#
# ## Second Normal Form (2NF)
# ### For a table to be in the Second Normal Form,
# #### 1. It should be in the First Normal form.
# #### 2. And, it should not have Partial Dependency.
#
# ## Third Normal Form (3NF)
# ### A table is said to be in the Third Normal Form when,
# #### 1. It is in the Second Normal form.
# #### 2. And, it doesn't have Transitive Dependency.
#
# ## Boyce and Codd Normal Form (BCNF)
# #### 1. Boyce and Codd Normal Form is a higher version of the Third Normal form. This form deals with certain type of anomaly that is not handled by 3NF. A 3NF table which does not have multiple overlapping candidate keys is said to be in BCNF. For a table to be in BCNF, following conditions must be satisfied:
#
# #### 2. R must be in 3rd Normal Form
# #### 3. and, for each functional dependency ( X → Y ), X should be a super Key.
# <img src="nf2.png">
